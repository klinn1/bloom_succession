# %%
from scipy.integrate import *
from pandas import *
from numpy import *
from pylab import *
from scipy import *
import math
from scipy.interpolate import InterpolatedUnivariateSpline

# %%
# time change (discrete time)
T = 360.0 
delt = 1.0/240.0
t = np.linspace(0, T, int(T/delt)) #time array
#t = np.linspace(0,T,int(T/dt))
#print(t)

# array  to store  the  solution
N = np.zeros(len(t))
P1 = np.zeros(len(t))
P2 = np.zeros(len(t))
N[0] = 100
P1[0] = 50
P2[0] = 50
y0 = np.array([N[0], P1[0], P2[0]]) #create an array with your starting values for odeint
print(y0)
# Out:
# [100.  50.  50.]

# %%
zetas = np.linspace(0,50,50)
k = 0.04
S_r = 0.7
print(len(zetas))
# Out:
# 50

# %%
alpha_naughts = (sin(((t)/T*2*math.pi-math.pi/2))+1)/2
#alpha_knots = ones(int(T/delt))
plt.plot(t,alpha_naughts)

# %%
alphas = []
for alpha_naught in alpha_naughts:
    alpha = alpha_naught * np.exp(-k*zetas)
    alphas.append(alpha)
light_att = array(alphas)
lights = light_att.T

print(light_att.shape)
print(zetas.shape)
print(alpha_naughts.shape)
print(lights.shape)
# Out:
# (86400, 50)
# (50,)
# (86400,)
# (50, 86400)

# %%
print(lights.shape)
# Out:
# (50, 86400)

# %%
plt.contourf(t,zetas,lights,cmap = 'plasma')
plt.gca().invert_yaxis()
plt.xlabel('Time (Days)', color = 'k')
plt.ylabel('Depth (Meters)', color = 'k')
plt.title('Light Intensity')
plt.colorbar()
plt.savefig('light_cycle_variable')

# %%
alpha_naughts_interp = InterpolatedUnivariateSpline(t, alpha_naughts)

# %%
plt.plot(t, alpha_naughts)
plt.plot(t, alpha_naughts_interp(t), 'r')

# %%
def nbl_model(y, t, zeta, delta):
    N, P1, P2 = y[0], y[1], y[2]
    alpha_naught = alpha_naughts_interp(t)
    if alpha_naught < 0:
        alpha_naught = 0.
    alpha = alpha_naught * np.exp(-k*zeta)
    dNdt = S_r - alpha*N/(N+4000)*P1 - alpha*N/(N+100)*P2
    dP1dt = alpha*N/(N+4000)*P1 - delta*P1
    dP2dt = alpha*N/(N+100)*P2 - delta*P2
    return np.array([dNdt, dP1dt, dP2dt])

# %%
delta = 0.01
tim = []
for zeta in zetas:
    integ_sivz = odeint(nbl_model, y0, t, args=(zeta, delta))
    tim.append(integ_sivz)
sols = array(tim)
print(sols)
# Out:
# [[[100.          50.          50.        ]
#   [100.0029167   49.99791669  49.99791669]
#   [100.0058334   49.99583346  49.99583346]
#   ...
#   [ 25.14936003   1.54317461  54.65705572]
#   [ 25.15227673   1.54311031  54.65477837]
#   [ 25.15519343   1.54304602  54.65250111]]
#
#  [[100.          50.          50.        ]
#   [100.0029167   49.99791669  49.99791669]
#   [100.0058334   49.99583346  49.99583346]
#   ...
#   [ 25.51101981   1.54346516  54.48370251]
#   [ 25.51393651   1.54340085  54.48143237]
#   [ 25.51685321   1.54333654  54.47916233]]
#
#  [[100.          50.          50.        ]
#   [100.0029167   49.99791669  49.99791669]
#   [100.0058334   49.99583346  49.99583346]
#   ...
#   [ 25.87798454   1.54376398  54.30968067]
#   [ 25.88090124   1.54369966  54.30741779]
#   [ 25.88381794   1.54363534  54.305155  ]]
#
#  ...
#
#  [[100.          50.          50.        ]
#   [100.0029167   49.99791669  49.99791669]
#   [100.0058334   49.99583346  49.99583346]
#   ...
#   [ 48.92075496   1.57311746  47.27782965]
#   [ 48.92367166   1.57305191  47.27585976]
#   [ 48.92658837   1.57298637  47.27388995]]
#
#  [[100.          50.          50.        ]
#   [100.0029167   49.99791669  49.99791669]
#   [100.0058334   49.99583346  49.99583346]
#   ...
#   [ 49.58180482   1.57441893  47.21375655]
#   [ 49.58472152   1.57435333  47.21178933]
#   [ 49.58763822   1.57428773  47.20982219]]
#
#  [[100.          50.          50.        ]
#   [100.0029167   49.99791669  49.99791669]
#   [100.0058334   49.99583346  49.99583346]
#   ...
#   [ 50.24705671   1.57577283  47.16092288]
#   [ 50.24997341   1.57570717  47.15895786]
#   [ 50.25289011   1.57564152  47.15699292]]]

# %%
plt.contourf(t,zetas,sols[:,:,0],cmap = 'plasma')
plt.gca().invert_yaxis()
plt.xlabel('Time (Days)', color = 'k')
plt.ylabel('Depth (Meters)', color = 'k')
plt.title('Nutrients')
plt.colorbar()
plt.savefig('light_cycle_variable_np_nutrients')

# %%
plt.contourf(t,zetas,sols[:,:,1],cmap = 'plasma')
plt.gca().invert_yaxis()
plt.xlabel('Time (Days)', color = 'k')
plt.ylabel('Depth (Meters)', color = 'k')
plt.title('Biomass of Diatoms')
plt.colorbar()
plt.savefig('light_cycle_variable_np_biomass')

# %%
plt.contourf(t,zetas,sols[:,:,2],cmap = 'plasma')
plt.gca().invert_yaxis()
plt.xlabel('Time (Days)', color = 'k')
plt.ylabel('Depth (Meters)', color = 'k')
plt.title('Biomass of Microcystis')
plt.colorbar()
plt.savefig('light_cycle_variable_np_biomass')
