# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import lognorm
from scipy import stats

# %%
mu = 3.0 
fig, ax = plt.subplots(1, 1)
x = np.linspace(lognorm.ppf(0, mu), 3)
print(x)
print(lognorm.pdf(x, mu))
ax.plot(x, lognorm.pdf(x, mu),'r-', lw=5, alpha=0.6, label='lognorm pdf')
# Out:
# [0.         0.06122449 0.12244898 0.18367347 0.24489796 0.30612245
#  0.36734694 0.42857143 0.48979592 0.55102041 0.6122449  0.67346939
#  0.73469388 0.79591837 0.85714286 0.91836735 0.97959184 1.04081633
#  1.10204082 1.16326531 1.2244898  1.28571429 1.34693878 1.40816327
#  1.46938776 1.53061224 1.59183673 1.65306122 1.71428571 1.7755102
#  1.83673469 1.89795918 1.95918367 2.02040816 2.08163265 2.14285714
#  2.20408163 2.26530612 2.32653061 2.3877551  2.44897959 2.51020408
#  2.57142857 2.63265306 2.69387755 2.75510204 2.81632653 2.87755102
#  2.93877551 3.        ]
# [0.         1.40805896 0.85001253 0.61724363 0.48645826 0.40186809
#  0.34238519 0.29815641 0.26392565 0.23661983 0.21431664 0.19574943
#  0.18004832 0.16659547 0.15493954 0.14474295 0.13574799 0.12775447
#  0.12060445 0.11417164 0.10835377 0.1030672  0.0982428  0.09382294
#  0.0897592  0.08601058 0.08254216 0.07932396 0.07633016 0.07353833
#  0.07092897 0.06848497 0.06619131 0.06403472 0.06200346 0.06008706
#  0.05827621 0.05656256 0.05493862 0.05339764 0.05193354 0.0505408
#  0.04921443 0.04794988 0.04674301 0.04559005 0.04448752 0.04343226
#  0.04242136 0.04145214]

# %%
plt.hist(lognorm.pdf(x, mu), normed=True)

# find minimum and maximum of xticks, so we know
# where we should compute theoretical distribution
xt = plt.xticks()[0]  
xmin, xmax = min(xt), max(xt)  
lnspc = np.linspace(xmin, xmax, len(x))
x = np.linspace(lognorm.ppf(0, mu), 3)

# normal distribution 
m, s = stats.norm.fit(lognorm.pdf(x, mu)) # mean and standard deviation  
pdf_g = stats.norm.pdf(lnspc, m, s) #theoretical values in interval  
plt.plot(lnspc, pdf_g, label="Norm")

# %%
psi = 1.2
phi = mu**psi

fig, ax = plt.subplots(1, 1)
x = np.linspace(lognorm.ppf(0, phi), 0.2)
print(x)
print(lognorm.pdf(x, phi))
ax.plot(x, lognorm.pdf(x, phi),'r-', lw=5, alpha=0.6, label='lognorm pdf')
# Out:
# [0.         0.00408163 0.00816327 0.0122449  0.01632653 0.02040816
#  0.0244898  0.02857143 0.03265306 0.03673469 0.04081633 0.04489796
#  0.04897959 0.05306122 0.05714286 0.06122449 0.06530612 0.06938776
#  0.07346939 0.07755102 0.08163265 0.08571429 0.08979592 0.09387755
#  0.09795918 0.10204082 0.10612245 0.11020408 0.11428571 0.11836735
#  0.12244898 0.12653061 0.13061224 0.13469388 0.13877551 0.14285714
#  0.14693878 0.15102041 0.15510204 0.15918367 0.16326531 0.16734694
#  0.17142857 0.1755102  0.17959184 0.18367347 0.1877551  0.19183673
#  0.19591837 0.2       ]
# [0.         8.85116823 5.71573834 4.35557775 3.56618856 3.04139338
#  2.66341305 2.37631054 2.14979221 1.96589642 1.8132398  1.68422921
#  1.57358966 1.4775334  1.39326482 1.31867221 1.25212846 1.19235812
#  1.13834628 1.08927453 1.04447515 1.00339755 0.9655834  0.9306479
#  0.89826543 0.86815848 0.84008899 0.81385152 0.78926777 0.76618221
#  0.74445853 0.7239767  0.70463062 0.6863261  0.66897927 0.65251513
#  0.63686645 0.62197273 0.60777942 0.59423715 0.58130117 0.56893079
#  0.55708892 0.5457417  0.53485813 0.5244098  0.51437058 0.50471644
#  0.4954252  0.48647639]

# %%
plt.hist(lognorm.pdf(x, phi), normed=True)

# find minimum and maximum of xticks, so we know
# where we should compute theoretical distribution
xt = plt.xticks()[0]  
xmin, xmax = min(xt), max(xt)  
lnspc = np.linspace(xmin, xmax, len(x))
x = np.linspace(lognorm.ppf(0, phi), 0.2)

# normal distribution 
m, s = stats.norm.fit(lognorm.pdf(x, phi)) # mean and standard deviation  
pdf_g = stats.norm.pdf(lnspc, m, s) # theoretical values interval  
plt.plot(lnspc, pdf_g, label="Norm")
